# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/WineQT.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df['wineQuality'] = np.where(df['quality'] >= 6, 'good', 'bad')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id wineQuality
# 0      9.4        5   0         bad
# ...

# %%
df['wineQuality_ord'] = df['wineQuality'].map({
    'bad': 0,
    'good': 1
})

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id wineQuality  wineQuality_ord
# ...

# %%
count = df['wineQuality_ord'].value_counts()
count
# Out:
# wineQuality_ord
# 1    621
# 0    522
# Name: count, dtype: int64

# %%
plt.pie(x = count, autopct='%.2f%%', labels=count.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x312ac9cd0>,
# ...
#  [Text(-0.14919729137785362, 1.089834927062586, '1'),
#   Text(0.14919712681735625, -1.0898349495907378, '0')],
#  [Text(-0.08138034075155652, 0.5944554147614104, '54.33%'),
#   Text(0.08138025099128522, -0.5944554270494933, '45.67%')])

# %%
sns.boxplot(data=df, x=df['fixed acidity'])
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
sns.boxplot(data=df, x=df['volatile acidity'])
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
sns.boxplot(data=df, x=df['citric acid'])
# Out:
# <Axes: xlabel='citric acid'>

# %%
df.query('`citric acid` > 0.9')
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 103            9.2              0.52          1.0             3.4       0.61
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 103                 32.0                  69.0   0.9996  2.74        2.0
#
#      alcohol  quality   Id wineQuality  wineQuality_ord
# 103      9.4        4  151         bad                0

# %%
sns.boxplot(data=df, x=df['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
sns.boxplot(data=df, x=df['chlorides'])
# Out:
# <Axes: xlabel='chlorides'>

# %%
sns.boxplot(data=df, x=df['free sulfur dioxide'])
# Out:
# <Axes: xlabel='free sulfur dioxide'>

# %%
sns.boxplot(data=df, x=df['total sulfur dioxide'])
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %%
sns.boxplot(data=df, x=df['density'])
# Out:
# <Axes: xlabel='density'>

# %%
df.query('density < 0.992')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 96              5.2              0.34         0.00            1.80      0.050
# 98              5.2              0.34         0.00            1.80      0.050
# 249             6.1              0.21         0.40            1.40      0.066
# 419             5.0              0.42         0.24            2.00      0.060
# 589             4.9              0.42         0.00            2.10      0.048
# 597             6.7              0.28         0.28            2.40      0.012
# 598             6.7              0.28         0.28            2.40      0.012
# 701             6.4              0.69         0.00            1.65      0.055
# 714             8.0              0.18         0.37            0.90      0.049
# 787             5.0              0.40         0.50            4.30      0.046
# 868             5.1              0.42         0.00            1.80      0.044
# ...

# %%
df.query('density > 1.002')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 259            12.8             0.615         0.66             5.8      0.083
# 260            12.8             0.615         0.66             5.8      0.083
# 311            15.6             0.685         0.76             3.7      0.100
# 339            10.6             0.280         0.39            15.5      0.069
# 397            15.5             0.645         0.49             4.2      0.095
# 399            15.6             0.645         0.49             4.2      0.095
# 400            13.0             0.470         0.49             4.3      0.085
# 404            13.0             0.470         0.49             4.3      0.085
# 430            10.1             0.650         0.37             5.1      0.110
# 627            10.7             0.900         0.34             6.6      0.112
# 1022           10.2             0.540         0.37            15.4      0.214
# ...

# %%
df.query('density == 0.997')
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2              7.8             0.760         0.04            2.30      0.092
# 33             7.7             0.935         0.43            2.20      0.114
# 37             8.6             0.380         0.36            3.00      0.081
# 56             7.4             0.500         0.47            2.00      0.086
# 132            6.7             0.620         0.21            1.90      0.079
# 252           10.5             0.420         0.66            2.95      0.116
# 290           10.6             0.480         0.64            2.20      0.111
# 333            9.6             0.540         0.42            2.40      0.081
# 454            8.9             0.290         0.35            1.90      0.067
# 484            8.1             0.780         0.23            2.60      0.059
# 486            8.1             0.780         0.23            2.60      0.059
# ...

# %%
sns.boxplot(data=df, x=df['pH'])
# Out:
# <Axes: xlabel='pH'>

# %%
df.query('pH < 2.9')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 103             9.2              0.52         1.00             3.4      0.610
# 310            12.6              0.31         0.72             2.2      0.072
# 388            14.3              0.31         0.74             1.8      0.075
# 461            10.7              0.43         0.39             2.2      0.106
# 466            10.7              0.43         0.39             2.2      0.106
# 714             8.0              0.18         0.37             0.9      0.049
# 1047           10.0              0.69         0.11             1.4      0.084
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 103                  32.0                  69.0  0.99960  2.74       2.00
# 310                   6.0                  29.0  0.99870  2.88       0.82
# 388                   6.0                  15.0  1.00080  2.86       0.79
# ...

# %%
df.query('pH > 3.7')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              4.6             0.520         0.15            2.10      0.054
# 66              5.0             1.020         0.04            1.40      0.045
# 396             5.0             1.040         0.24            1.60      0.050
# 419             5.0             0.420         0.24            2.00      0.060
# 493             5.1             0.470         0.02            1.30      0.034
# 589             4.9             0.420         0.00            2.10      0.048
# 785             5.4             0.420         0.27            2.00      0.092
# 923             5.2             0.645         0.00            2.15      0.080
# 933             5.4             0.740         0.00            1.20      0.041
# 935             5.0             0.740         0.00            1.20      0.041
# 1063            5.6             0.540         0.04            1.70      0.049
#
# ...

# %%
sns.boxplot(data=df, x=df['sulphates'])
# Out:
# <Axes: xlabel='sulphates'>

# %%
sns.boxplot(data=df, x=df['alcohol'])
# Out:
# <Axes: xlabel='alcohol'>

# %%
sns.boxplot(data=df, x=df['quality'])
# Out:
# <Axes: xlabel='quality'>

# %%
df.query('quality >= 8.0')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 190             7.9              0.35         0.46             3.6      0.078
# 197            10.3              0.32         0.45             6.4      0.073
# 271             5.6              0.85         0.05             1.4      0.045
# 310            12.6              0.31         0.72             2.2      0.072
# 321            11.3              0.62         0.67             5.2      0.086
# 340             9.4              0.30         0.56             2.8      0.080
# 349            10.7              0.35         0.53             2.6      0.070
# 352            10.7              0.35         0.53             2.6      0.070
# 419             5.0              0.42         0.24             2.0      0.060
# 747             9.1              0.40         0.50             1.8      0.071
# 769            10.0              0.26         0.54             1.9      0.083
# ...

# %%
df.drop(columns=['Id', 'wineQuality'], inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  wineQuality_ord
# 0      9.4        5                0
# ...

# %%
X = df.drop('wineQuality_ord', axis=1)
y = df['wineQuality_ord']

# %%
X.shape, y.shape
# Out:
# ((1143, 12), (1143,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((857, 12), (286, 12), (857,), (286,))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train_scaled, y_train)
y_pred_lr = lr.predict(X_test_scaled)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       128
#            1       1.00      1.00      1.00       158
#
#     accuracy                           1.00       286
#    macro avg       1.00      1.00      1.00       286
# weighted avg       1.00      1.00      1.00       286
